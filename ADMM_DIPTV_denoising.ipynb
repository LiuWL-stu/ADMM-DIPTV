# %% [markdown]
# This is the code of our **ADMM DIP-TV** described in the paper:
#
# https://arxiv.org/abs/2009.11380
#
# This is the version with a uniform weight, that is without the weighted TV.
# - Select `name` below to switch between the images.
# - Change the `weight`depending on the noise.

# %%
# Mounting my Google Drive and set the cwd on my imagefolder
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# %cd /content/drive/My Drive/ADMM-DIPTV
# %cd /content/drive/MyDrive/ADMM-DIPTV-master/ADMM-DIPTV-master
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive/ADMM-DIPTV-master/ADMM-DIPTV-master

# %% [markdown]
# # Import libs

# %%
from __future__ import print_function
import matplotlib.pyplot as plt
# %matplotlib inline

import os

import numpy as np
import random
from models import *

import torch
import torch.optim

from skimage.metrics import peak_signal_noise_ratio as compare_psnr
from utils.denoising_utils import *
from utils.utils import *

torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark =True
dtype = torch.cuda.FloatTensor

imsize = -1
PLOT = True
sigma = 20 #25
sigma_ = sigma/255.

# %%
name = 'butterfly.png'
fname = f"data2/denoising/%s"%(name)

# %% [markdown]
# # Load image

# %%
# Add synthetic noise
img_pil = crop_image(get_image(fname, imsize)[0], d=32)
img_np = pil_to_np(img_pil)

# pay attention!
if img_np.shape[0]==2:
  img_np_temp = np.zeros((3,img_np.shape[1], img_np.shape[2]))
  img_np_temp[0,:,:] = img_np[0,:,:]
  img_np_temp[1,:,:] = img_np[0,:,:]
  img_np_temp[2,:,:] = img_np[0,:,:]
  img_np = img_np_temp
if img_np.shape[0]==4:
  img_np = img_np[:-1,:,:]

img_noisy_pil, img_noisy_np = get_noisy_image(img_np, sigma_)

if PLOT:
    plot_image_grid([img_np, img_noisy_np], 4, 5);

print(img_np.shape)
# Out:
# (3, 256, 256)

# %% [markdown]
# # Setup

# %%
INPUT = 'noise'
pad = 'reflection'
OPT_OVER = 'net'

reg_noise_std = 1./20.

show_every = 5

num_iter = 100
input_depth = 3
figsize = 10


net = get_net(input_depth, 'skip', pad,
              skip_n33d=128,
              skip_n33u=128,
              skip_n11=4,
              num_scales=5,
              upsample_mode='bilinear').type(dtype)

net_input = get_noise(input_depth, INPUT, (img_pil.size[1], img_pil.size[0])).type(dtype).detach()

# Compute number of parameters
s  = sum([np.prod(list(p.size())) for p in net.parameters()]);
print ('Number of params: %d' % s)

# Loss
mse = torch.nn.MSELoss().type(dtype)
# Out:
# Number of params: 2184307

# %%
size = img_np.shape
h = size[-2]
w = size[-1]
Dh_psf = np.array([ [0, 0, 0], [1, -1, 0], [0, 0, 0]])
Dv_psf = np.array([ [0, 1, 0], [0, -1, 0], [0, 0, 0]])
Id_psf = np.array([[1]])

Id_DFT = torch.from_numpy(psf2otf(Id_psf, [h,w])).cuda()
Dh_DFT = torch.from_numpy(psf2otf(Dh_psf, [h,w])).cuda()
Dv_DFT = torch.from_numpy(psf2otf(Dv_psf, [h,w])).cuda()

DhT_DFT = torch.conj(Dh_DFT)
DvT_DFT = torch.conj(Dv_DFT)

# %%
LR = 1e-3
optimizer = torch.optim.Adam(net.parameters(), lr=LR)

# %% [markdown]
# # Optimize

# %%
net_input_saved = net_input.detach().clone()
noise = net_input.detach().clone()
out_avg = None
last_net = None
psrn_noisy_last = 0

img_noisy_torch = np_to_torch(img_noisy_np).type(dtype)
u = 0*img_noisy_torch.detach().clone()
# t_h = 0*img_noisy_torch.detach().clone()
# t_v = 0*img_noisy_torch.detach().clone()

# mu_f = torch.zeros(net_input.shape, device=0)
# mu_t_h = torch.zeros(net_input.shape, device=0)
# mu_t_v = torch.zeros(net_input.shape, device=0)

# beta_t = 10
# weight = 0.1

# --- TGV 频域预计算 ---
DhT_Dh = torch.fft.ifft2(Dh_DFT * DhT_DFT, dim=(-2, -1)).real
DvT_Dv = torch.fft.ifft2(Dv_DFT * DvT_DFT, dim=(-2, -1)).real

# --- TGV 变量初始化 ---
zero_t = torch.zeros_like(img_noisy_torch).type(dtype)
# 1. 向量场 V
p_h, p_v = zero_t.clone(), zero_t.clone()
# 2. 一阶和二阶辅助变量 Y, Z
y_h, y_v = zero_t.clone(), zero_t.clone()
z_hh, z_hv, z_vv = zero_t.clone(), zero_t.clone(), zero_t.clone()
# 3. 拉格朗日乘子
yy_h, yy_v = zero_t.clone(), zero_t.clone()
zz_hh, zz_hv, zz_vv = zero_t.clone(), zero_t.clone(), zero_t.clone()

# --- TGV 超参数 ---
# 注意：原来 TV 的 beta_t 对应这里的 mu1
alpha1, alpha0 = 1.0, 3.0
mu1, mu2 = 4.0, 1.0
gamma2, gamma3 = 5.0, 5.0
a = alpha1 * mu1
b = alpha0 * mu2

#---------

inner_iterations = 50

loss_values = []
fun_values = []
psnr_values = []
running_loss=0

for i in range(num_iter):

    if inner_iterations>1:
      optimizer = torch.optim.Adam(net.parameters(), lr=LR)

    for j in range(inner_iterations):
      optimizer.zero_grad()

      #First problem
      out = net(net_input)
      [Dh_out, Dv_out] = D(out, Dh_DFT, Dv_DFT)

      total_loss = norm2_loss(out-img_noisy_torch)
      # total_loss += (beta_t/2)*norm2_loss(Dh_out-(t_h-mu_t_h).detach()) + (beta_t/2)*norm2_loss(Dv_out-(t_v-mu_t_v).detach())
      # TGV 约束：迫使网络的输出梯度，去逼近 "剥离了向量场后的真实边缘"
      total_loss += (mu1/2) * norm2_loss(Dh_out - (y_h + p_h - yy_h).detach())
      total_loss += (mu1/2) * norm2_loss(Dv_out - (y_v + p_v - yy_v).detach())

      total_loss.backward()
      optimizer.step()

    running_loss = total_loss.item()
    loss_values.append(running_loss)

    out = net(net_input)

    [Dh_out, Dv_out] = D(out, Dh_DFT, Dv_DFT)

    # #TV problem: second problem
    # q_h                 = Dh_out + mu_t_h
    # q_v                 = Dv_out + mu_t_v
    # q_norm              = torch.sqrt(torch.pow(q_h,2) + torch.pow(q_v,2))
    # q_norm[q_norm == 0] = weight/beta_t
    # q_norm              = torch.clamp( q_norm - weight/beta_t , min=0 )/q_norm
    # t_h                 = (q_norm * q_h).detach().clone()
    # t_v                 = (q_norm * q_v).detach().clone()

    # #Ascent step: updating lagrangian parameter
    # mu_t_h = (mu_t_h + (Dh_out- t_h)).detach().clone()
    # mu_t_v = (mu_t_v + (Dv_out- t_v)).detach().clone()



    with torch.no_grad():
      # 1. 更新向量场 P (解决 V 子问题)
      [Dh_p_h, Dv_p_h] = D(p_h, Dh_DFT, Dv_DFT)
      [Dh_p_v, Dv_p_v] = D(p_v, Dh_DFT, Dv_DFT)

      [DhT_zhh, DvT_zhh] = D(z_hh - zz_hh, DhT_DFT, DvT_DFT)
      [DhT_zvv, DvT_zvv] = D(z_vv - zz_vv, DhT_DFT, DvT_DFT)
      [DhT_zhv, DvT_zhv] = D(-0.5 * Dh_p_v + z_hv - zz_hv, DhT_DFT, DvT_DFT)
      [DvT_zhv_sym, _]   = D(-0.5 * Dv_p_h + z_hv - zz_hv, DhT_DFT, DvT_DFT)

      # 频域求逆 (克莱姆法则)
      p_h = ((a * (Dh_out - y_h + yy_h) + b * DhT_zhh + b * DvT_zhv) / (a + b * (DhT_Dh + 0.5 * DvT_Dv))).clone()
      p_v = ((a * (Dv_out - y_v + yy_v) + b * DvT_zvv + b * DvT_zhv_sym) / (a + b * (DvT_Dv + 0.5 * DhT_Dh))).clone()

      # 重新计算新向量场的差分
      [Dh_p_h, Dv_p_h] = D(p_h, Dh_DFT, Dv_DFT)
      [Dh_p_v, Dv_p_v] = D(p_v, Dh_DFT, Dv_DFT)
      ep_hh = Dh_p_h.clone()
      ep_vv = Dv_p_v.clone()
      ep_hv = (0.5 * (Dv_p_h + Dh_p_v)).clone()

      # 2. 更新一阶辅助变量 Y (去除边缘噪声)
      y_h = shrink2(Dh_out - p_h + yy_h, alpha1 / mu1)
      y_v = shrink2(Dv_out - p_v + yy_v, alpha1 / mu1)

      # 3. 更新二阶辅助变量 Z (平滑区域去噪)
      z_hh = shrink2(ep_hh + zz_hh, alpha0 / mu2)
      z_hv = shrink2(ep_hv + zz_hv, alpha0 / mu2)
      z_vv = shrink2(ep_vv + zz_vv, alpha0 / mu2)

      # 4. 更新拉格朗日乘子
      yy_h += gamma2 * (Dh_out - p_h - y_h)
      yy_v += gamma2 * (Dv_out - p_v - y_v)
      zz_hh += gamma3 * (ep_hh - z_hh)
      zz_hv += gamma3 * (ep_hv - z_hv)
      zz_vv += gamma3 * (ep_vv - z_vv)


    psrn_noisy = compare_psnr(img_noisy_np, out.detach().cpu().numpy()[0])
    psrn_gt    = compare_psnr(img_np, out.detach().cpu().numpy()[0])
    psnr_values.append(psrn_gt)

    if  PLOT and i % show_every == 0:
        out_np = torch_to_np(out)
        plot_image_grid([np.clip(out_np, 0, 1), img_np], factor=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7400/2118235760.py in <cell line: 0>()
#     114
#     115       # 2. 更新一阶辅助变量 Y (去除边缘噪声)
# --> 116       y_h = shrink2(Dh_out - p_h + yy_h, alpha1 / mu1)
#     117       y_v = shrink2(Dv_out - p_v + yy_v, alpha1 / mu1)
#     118
#
# NameError: name 'shrink2' is not defined

# %%
out_np = torch_to_np(net(net_input))
plot_image_grid([np.clip(out_np, 0, 1), img_np,img_noisy_np], factor=18);

# %%
plt.plot(psnr_values)
plt.title(f"Best PSNR:%.2f - Last PSNR:%.2f"%(np.max(psnr_values), psnr_values[-1]))
plt.show()

plt.plot(loss_values)
plt.title("Running loss")
plt.show()

# %%
from PIL import Image

#Saving output image

folder = "ADMM_DIPTV"
path = f"results_ICCSA/%s/%s_%s_%d"%(folder, folder, name[:-4], sigma)

out_np=255*out_np
print(np.amax(out_np))
u=out_np.transpose(1, 2, 0)
np.savetxt(f'%s.txt'%path,u[:,:,0])

u=u.astype(np.uint8)
print(u.shape)

im = Image.fromarray(u)
im.save(f'%s.png'%path)
# Out:
# 59161.34
# (256, 256, 3)

# %%
#Saving output PSNR
folder = "ADMM_DIPTV"
file_name = "ADMM_DIPTV_psnr"
path = f"results_ICCSA/%s/%s_%s_%d"%(folder, file_name, name[:-4], sigma)
np.savetxt(f'%s.txt'%path,psnr_values)

#Saving noisy image
folder = "ADMM_DIPTV"
file_name = "ADMM_DIPTV_noisy"
path = f"results_ICCSA/%s/%s_%s_%d"%(folder, file_name, name[:-4], sigma)

img_noisy_np=255*img_noisy_np
u=img_noisy_np.transpose(1, 2, 0)

u=u.astype(np.uint8)
print(u.shape)

im = Image.fromarray(u)
im.save(f'%s.png'%path)
# Out:
# (256, 256, 3)
